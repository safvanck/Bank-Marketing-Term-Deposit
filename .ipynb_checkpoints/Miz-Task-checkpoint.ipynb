# %% [raw]
# @author : Safvan CK

# %% [markdown]
# ## Tasks
# 1. EDA
# 2. Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import RandomizedSearchCV

# %%
# %matplotlib inline

# %%
from sklearn.pipeline import Pipeline
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier, LogisticRegression
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
df = pd.read_csv('data/bank-full.csv', sep=';')

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
all_cols=list(df.columns)

# %%
df.describe(())
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 50%       -1.000000      0.000000
# max      871.000000    275.000000

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
pd.plotting.scatter_matrix(df);

# %%
df.corr()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.097783 -0.009120 -0.004648  0.004760 -0.023758  0.001288
# balance   0.097783  1.000000  0.004503  0.021560 -0.014578  0.003435  0.016674
# day      -0.009120  0.004503  1.000000 -0.030206  0.162490 -0.093044 -0.051710
# duration -0.004648  0.021560 -0.030206  1.000000 -0.084570 -0.001565  0.001203
# campaign  0.004760 -0.014578  0.162490 -0.084570  1.000000 -0.088628 -0.032855
# pdays    -0.023758  0.003435 -0.093044 -0.001565 -0.088628  1.000000  0.454820
# previous  0.001288  0.016674 -0.051710  0.001203 -0.032855  0.454820  1.000000

# %%
corrmap = df.corr()
plt.figure(figsize = (25,25))
sns.heatmap(corrmap, square = True)

# %%
iCat_cols = np.where(df.dtypes =='object')[0]

# %%
cat_cols=df.columns[iCat_cols]

# %%
_=[print(i,':\n',df[i].value_counts(),'\n--------------------------') for i in cat_cols]
# Out:
# job :
#  blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64
# --------------------------
# marital :
#  married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64
# --------------------------
# education :
#  secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64
# --------------------------
# default :
#  no     44396
# yes      815
# Name: default, dtype: int64
# --------------------------
# housing :
#  yes    25130
# no     20081
# Name: housing, dtype: int64
# --------------------------
# loan :
#  no     37967
# yes     7244
# Name: loan, dtype: int64
# --------------------------
# contact :
#  cellular     29285
# unknown      13020
# telephone     2906
# Name: contact, dtype: int64
# --------------------------
# month :
#  may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: month, dtype: int64
# --------------------------
# poutcome :
#  unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: poutcome, dtype: int64
# --------------------------
# y :
#  no     39922
# yes     5289
# Name: y, dtype: int64
# --------------------------

# %%
df['y'].value_counts().plot.bar()

# %% [markdown]
# This is an imbalanced data cause most of the result in the dependent variable y are 'no'

# %%
for col in cat_cols:
    pd.crosstab(df[col],df['y']).plot(kind='bar')

# %%
for col in set(all_cols)-set(cat_cols):
    plt.figure(figsize=(15,7))
    sns.distplot(a=df[col])

# %% [markdown]
# # Data cleaning/creating/removing/preprocessing, etc.

# %%
df['pdays'].value_counts().sort_values(ascending=False)
# Out:
# -1      36954
#  182      167
#  92       147
#  183      126
#  91       126
#         ...
#  437        1
#  54         1
#  470        1
#  854        1
#  32         1
# Name: pdays, Length: 559, dtype: int64

# %% [markdown]
# count of the value '-1' id far greater than others

# %%
data_df=df.copy()

# %%
#making new feature (Previously contacted or not) (from 'pdays')
data_df['prev_contacted']=df['pdays'].apply(lambda x: 0 if x==-1 else 1)

# %%
# Encoding:
data_df['y']=df['y'].apply(lambda x: 0 if x=='no' else 1)
data_df['default']=df['default'].apply(lambda x: 0 if x=='no' else 1)
data_df['housing']=df['housing'].apply(lambda x: 0 if x=='no' else 1)
data_df['loan']=df['loan'].apply(lambda x: 0 if x=='no' else 1)

# %%
# #impute missing values:

# data_df['contact'].fillna(data_df['contact'].median(), inplace = True)
# data_df['education'].fillna(data_df['education'].median(), inplace = True)

# %%
# we are not doing the missing value imputation since
# these are categorical values and imbalanced dataset and can't generate from other features

#Instead of imputation and removing, we treating the missing values as new values and
# doing one-hot encoding for the same

# %%
# Removing constant features (std==0 for numeric value column)
data_df.drop(data_df.std()[data_df.std()==0].index.values,axis=1,inplace=True)

# %%
# Removing constant features (unique value==1 for categorical value column)
def drop_constants(dff):
    columns=dff.columns.values
    for col in columns:
        if dff[col].nunique(dropna=False)==1:
            del dff[col]
    return dff

# %%
data_df=drop_constants(data_df)

# %%
#Removing known non-useful features
deleted_cols=['housing','poutcome']
data_df=data_df.drop(deleted_cols,axis=1)

# %%
onehot_cols=(set(cat_cols)-{'y','default','loan'})-set(deleted_cols)

# %%
data_df=pd.get_dummies(data_df,columns=onehot_cols,drop_first=True)

# %%
train_cols=list(data_df.columns)

# %%
train_cols.remove('y')

# %%
sc=StandardScaler()
X=sc.fit_transform(data_df[train_cols])
y=data_df['y']

# %%
# Balancing the imbalanced dataset:
sm=SMOTE(random_state=42)
X1,y1=sm.fit_resample(X,y)

# %%
x_train,x_test, y_train,y_test = train_test_split(X1,y1,random_state = 42,test_size=0.20)

# %% [markdown]
# # Training:

# %%
from xgboost.sklearn import XGBClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier#,VotingClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
result_cols = ["Classifier", "Accuracy"]
result_cols1 = ["Classifier","Precision", "Recall", 'F-measure']

result_frame = pd.DataFrame(columns=result_cols)
result_frame1 = pd.DataFrame(columns=result_cols1)

classifiers = [
        XGBClassifier(
                colsample_bylevel= 0.8,
                colsample_bytree= 0.5,
                gamma= 1.0,
                learning_rate= 0.2,
                max_depth= 15,
                min_child_weight= 0.5,
                n_estimators= 1000,
                reg_lambda= 100.0,
                silent= False,
                subsample= 1.0,
                objective='binary:logistic',
                nthread=8,
                seed=42),
        RandomForestClassifier(),
        AdaBoostClassifier(),
        ExtraTreesClassifier(bootstrap=False, criterion="entropy", max_features=0.6500000000000001,min_samples_leaf=1, min_samples_split=5, n_estimators=100),
        KNeighborsClassifier(3),
        DecisionTreeClassifier(),
        SGDClassifier(),
        LogisticRegression(multi_class='multinomial',solver ='newton-cg'),
        SVC(),
        GaussianNB()
]

# %%
# 2nd
colsample_bylevel= 0.8,
colsample_bytree= 0.5,
gamma= 1.0,
learning_rate= 0.2,
max_depth= 15,
min_child_weight= 0.5,
n_estimators= 1000,
reg_lambda= 100.0,
silent= False,
subsample= 1.0,

# %%
# 1st:
                learning_rate= 0.1,
                colsample_bylevel= 0.4,
                colsample_bytree= 0.6,
                gamma= 0.5,
                max_depth=15,
                min_child_weight= 0.5,
                reg_lambda= 10.0,
                n_estimators=1000,
                subsample=0.9,
                silent=False,
                objective='binary:logistic',
                nthread=8,
                scale_pos_weight=1,
                seed=42),

# %%
classifiers=[

]

# %%
type1_error = []
for clf in classifiers:
    name = clf.__class__.__name__
    clf.fit(x_train, y_train)
    predicted = clf.predict(x_test)
    acc = accuracy_score(y_test,predicted)
    precision = precision_score(y_test, predicted, average='weighted')
    rec = recall_score(y_test, predicted, average='weighted')
    f_measure = f1_score(y_test, predicted, average='weighted')
    type1_error.append([precision, rec, f_measure])

    print (name+' accuracy = '+str(acc*100)+'%\nprecision:',precision,'\nrecall:',rec)
    acc_field = pd.DataFrame([[name, acc*100]], columns=result_cols)
    result_frame = result_frame.append(acc_field)
    
    acc_field1 = pd.DataFrame([[name, precision, rec, f_measure]], columns=result_cols1)
    result_frame1 = result_frame1.append(acc_field1)
    confusion_mc = confusion_matrix(y_test, predicted)
    df_cm = pd.DataFrame(confusion_mc, 
                     index = [i for i in range(1,3)], columns = [i for i in range(1,3)])
    plt.figure(figsize=(5.5,4))
    sns.heatmap(df_cm, annot=True)
    plt.title(name+'\nAccuracy:{0:.3f}'.format(acc))
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
# Out:
# XGBClassifier accuracy = 94.68344918279166%
# precision: 0.946848889761833
# recall: 0.9468344918279166

# %%
plt.figure()
sns.set_color_codes("muted")
sns.barplot(x='Accuracy', y='Classifier', data=result_frame, color="r")

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy')
plt.show()

df1 = pd.melt(result_frame1, id_vars=['Classifier']).sort_values(['variable','value'])

plt.figure()
sns.barplot(x="Classifier", y="value", hue="variable", data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Parameter tuning:

# %%
param_grid = {
        'silent': [False],
        'max_depth': [6, 10, 15, 20],
        'learning_rate': [0.001, 0.01, 0.1, 0.2, 0,3],
        'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'colsample_bytree': [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'colsample_bylevel': [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'min_child_weight': [0.5, 1.0, 3.0, 5.0, 7.0, 10.0],
        'gamma': [0, 0.25, 0.5, 1.0],
        'reg_lambda': [0.1, 1.0, 5.0, 10.0, 50.0, 100.0],
        'n_estimators': [100,1000]}

# %%
clf=classifiers[0]

# %%
rs_clf = RandomizedSearchCV(clf, param_grid, n_iter=20,
                            n_jobs=1, verbose=2, cv=2,
                            scoring='neg_log_loss', refit=False, random_state=42)

# %%
rs_clf.fit(x_train, y_train)
# Out:
# Fitting 2 folds for each of 20 candidates, totalling 40 fits
# [CV] subsample=0.7, silent=False, reg_lambda=50.0, n_estimators=1000, min_child_weight=1.0, max_depth=15, learning_rate=0, gamma=1.0, colsample_bytree=0.6, colsample_bylevel=0.4
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  subsample=0.7, silent=False, reg_lambda=50.0, n_estimators=1000, min_child_weight=1.0, max_depth=15, learning_rate=0, gamma=1.0, colsample_bytree=0.6, colsample_bylevel=0.4, total=  37.8s
# [CV] subsample=0.7, silent=False, reg_lambda=50.0, n_estimators=1000, min_child_weight=1.0, max_depth=15, learning_rate=0, gamma=1.0, colsample_bytree=0.6, colsample_bylevel=0.4
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   37.8s remaining:    0.0s
# [CV]  subsample=0.7, silent=False, reg_lambda=50.0, n_estimators=1000, min_child_weight=1.0, max_depth=15, learning_rate=0, gamma=1.0, colsample_bytree=0.6, colsample_bylevel=0.4, total=  36.8s
# [CV] subsample=0.6, silent=False, reg_lambda=1.0, n_estimators=1000, min_child_weight=5.0, max_depth=10, learning_rate=0, gamma=0, colsample_bytree=0.6, colsample_bylevel=0.6
# [CV]  subsample=0.6, silent=False, reg_lambda=1.0, n_estimators=1000, min_child_weight=5.0, max_depth=10, learning_rate=0, gamma=0, colsample_bytree=0.6, colsample_bylevel=0.6, total=  34.5s
# [CV] subsample=0.6, silent=False, reg_lambda=1.0, n_estimators=1000, min_child_weight=5.0, max_depth=10, learning_rate=0, gamma=0, colsample_bytree=0.6, colsample_bylevel=0.6
# [CV]  subsample=0.6, silent=False, reg_lambda=1.0, n_estimators=1000, min_child_weight=5.0, max_depth=10, learning_rate=0, gamma=0, colsample_bytree=0.6, colsample_bylevel=0.6, total=  35.2s
# [CV] subsample=0.9, silent=False, reg_lambda=50.0, n_estimators=100, min_child_weight=3.0, max_depth=10, learning_rate=0, gamma=0, colsample_bytree=0.7, colsample_bylevel=0.4
# [CV]  subsample=0.9, silent=False, reg_lambda=50.0, n_estimators=100, min_child_weight=3.0, max_depth=10, learning_rate=0, gamma=0, colsample_bytree=0.7, colsample_bylevel=0.4, total=   2.8s
# [CV] subsample=0.9, silent=False, reg_lambda=50.0, n_estimators=100, min_child_weight=3.0, max_depth=10, learning_rate=0, gamma=0, colsample_bytree=0.7, colsample_bylevel=0.4
# [CV]  subsample=0.9, silent=False, reg_lambda=50.0, n_estimators=100, min_child_weight=3.0, max_depth=10, learning_rate=0, gamma=0, colsample_bytree=0.7, colsample_bylevel=0.4, total=   2.9s
# [CV] subsample=0.9, silent=False, reg_lambda=1.0, n_estimators=1000, min_child_weight=0.5, max_depth=15, learning_rate=0.1, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.8
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# [CV]  subsample=0.9, silent=False, reg_lambda=1.0, n_estimators=1000, min_child_weight=0.5, max_depth=15, learning_rate=0.1, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.8, total= 1.2min
# [CV] subsample=0.9, silent=False, reg_lambda=1.0, n_estimators=1000, min_child_weight=0.5, max_depth=15, learning_rate=0.1, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.8
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# [CV]  subsample=0.9, silent=False, reg_lambda=1.0, n_estimators=1000, min_child_weight=0.5, max_depth=15, learning_rate=0.1, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.8, total= 1.1min
# [CV] subsample=0.7, silent=False, reg_lambda=5.0, n_estimators=1000, min_child_weight=10.0, max_depth=20, learning_rate=3, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.4
# [CV]  subsample=0.7, silent=False, reg_lambda=5.0, n_estimators=1000, min_child_weight=10.0, max_depth=20, learning_rate=3, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.4, total=   6.7s
# [CV] subsample=0.7, silent=False, reg_lambda=5.0, n_estimators=1000, min_child_weight=10.0, max_depth=20, learning_rate=3, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.4
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# [CV]  subsample=0.7, silent=False, reg_lambda=5.0, n_estimators=1000, min_child_weight=10.0, max_depth=20, learning_rate=3, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.4, total=   6.4s
# [CV] subsample=1.0, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=3.0, max_depth=15, learning_rate=0.01, gamma=1.0, colsample_bytree=0.9, colsample_bylevel=0.9
# [CV]  subsample=1.0, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=3.0, max_depth=15, learning_rate=0.01, gamma=1.0, colsample_bytree=0.9, colsample_bylevel=0.9, total=   7.8s
# [CV] subsample=1.0, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=3.0, max_depth=15, learning_rate=0.01, gamma=1.0, colsample_bytree=0.9, colsample_bylevel=0.9
# [CV]  subsample=1.0, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=3.0, max_depth=15, learning_rate=0.01, gamma=1.0, colsample_bytree=0.9, colsample_bylevel=0.9, total=   7.6s
# [CV] subsample=0.5, silent=False, reg_lambda=0.1, n_estimators=1000, min_child_weight=1.0, max_depth=20, learning_rate=0.2, gamma=0.5, colsample_bytree=0.6, colsample_bylevel=0.4
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# [CV]  subsample=0.5, silent=False, reg_lambda=0.1, n_estimators=1000, min_child_weight=1.0, max_depth=20, learning_rate=0.2, gamma=0.5, colsample_bytree=0.6, colsample_bylevel=0.4, total=  35.0s
# [CV] subsample=0.5, silent=False, reg_lambda=0.1, n_estimators=1000, min_child_weight=1.0, max_depth=20, learning_rate=0.2, gamma=0.5, colsample_bytree=0.6, colsample_bylevel=0.4
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# [CV]  subsample=0.5, silent=False, reg_lambda=0.1, n_estimators=1000, min_child_weight=1.0, max_depth=20, learning_rate=0.2, gamma=0.5, colsample_bytree=0.6, colsample_bylevel=0.4, total=  37.3s
# [CV] subsample=0.5, silent=False, reg_lambda=5.0, n_estimators=100, min_child_weight=10.0, max_depth=15, learning_rate=0.2, gamma=0.5, colsample_bytree=0.7, colsample_bylevel=0.6
# [CV]  subsample=0.5, silent=False, reg_lambda=5.0, n_estimators=100, min_child_weight=10.0, max_depth=15, learning_rate=0.2, gamma=0.5, colsample_bytree=0.7, colsample_bylevel=0.6, total=   3.9s
# [CV] subsample=0.5, silent=False, reg_lambda=5.0, n_estimators=100, min_child_weight=10.0, max_depth=15, learning_rate=0.2, gamma=0.5, colsample_bytree=0.7, colsample_bylevel=0.6
# [CV]  subsample=0.5, silent=False, reg_lambda=5.0, n_estimators=100, min_child_weight=10.0, max_depth=15, learning_rate=0.2, gamma=0.5, colsample_bytree=0.7, colsample_bylevel=0.6, total=   4.0s
# [CV] subsample=0.7, silent=False, reg_lambda=50.0, n_estimators=1000, min_child_weight=1.0, max_depth=15, learning_rate=0.1, gamma=0.5, colsample_bytree=0.9, colsample_bylevel=0.7
# [CV]  subsample=0.7, silent=False, reg_lambda=50.0, n_estimators=1000, min_child_weight=1.0, max_depth=15, learning_rate=0.1, gamma=0.5, colsample_bytree=0.9, colsample_bylevel=0.7, total= 1.1min
# [CV] subsample=0.7, silent=False, reg_lambda=50.0, n_estimators=1000, min_child_weight=1.0, max_depth=15, learning_rate=0.1, gamma=0.5, colsample_bytree=0.9, colsample_bylevel=0.7
# [CV]  subsample=0.7, silent=False, reg_lambda=50.0, n_estimators=1000, min_child_weight=1.0, max_depth=15, learning_rate=0.1, gamma=0.5, colsample_bytree=0.9, colsample_bylevel=0.7, total= 1.1min
# [CV] subsample=0.8, silent=False, reg_lambda=100.0, n_estimators=100, min_child_weight=10.0, max_depth=10, learning_rate=0.01, gamma=0.25, colsample_bytree=0.7, colsample_bylevel=0.4
# [CV]  subsample=0.8, silent=False, reg_lambda=100.0, n_estimators=100, min_child_weight=10.0, max_depth=10, learning_rate=0.01, gamma=0.25, colsample_bytree=0.7, colsample_bylevel=0.4, total=   2.5s
# [CV] subsample=0.8, silent=False, reg_lambda=100.0, n_estimators=100, min_child_weight=10.0, max_depth=10, learning_rate=0.01, gamma=0.25, colsample_bytree=0.7, colsample_bylevel=0.4
# [CV]  subsample=0.8, silent=False, reg_lambda=100.0, n_estimators=100, min_child_weight=10.0, max_depth=10, learning_rate=0.01, gamma=0.25, colsample_bytree=0.7, colsample_bylevel=0.4, total=   2.5s
# [CV] subsample=0.7, silent=False, reg_lambda=50.0, n_estimators=100, min_child_weight=5.0, max_depth=15, learning_rate=0.1, gamma=0, colsample_bytree=0.7, colsample_bylevel=0.7
# [CV]  subsample=0.7, silent=False, reg_lambda=50.0, n_estimators=100, min_child_weight=5.0, max_depth=15, learning_rate=0.1, gamma=0, colsample_bytree=0.7, colsample_bylevel=0.7, total=   4.7s
# [CV] subsample=0.7, silent=False, reg_lambda=50.0, n_estimators=100, min_child_weight=5.0, max_depth=15, learning_rate=0.1, gamma=0, colsample_bytree=0.7, colsample_bylevel=0.7
# [CV]  subsample=0.7, silent=False, reg_lambda=50.0, n_estimators=100, min_child_weight=5.0, max_depth=15, learning_rate=0.1, gamma=0, colsample_bytree=0.7, colsample_bylevel=0.7, total=   4.6s
# [CV] subsample=0.9, silent=False, reg_lambda=1.0, n_estimators=1000, min_child_weight=1.0, max_depth=15, learning_rate=0.1, gamma=1.0, colsample_bytree=0.6, colsample_bylevel=0.9
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# [CV]  subsample=0.9, silent=False, reg_lambda=1.0, n_estimators=1000, min_child_weight=1.0, max_depth=15, learning_rate=0.1, gamma=1.0, colsample_bytree=0.6, colsample_bylevel=0.9, total=  53.3s
# [CV] subsample=0.9, silent=False, reg_lambda=1.0, n_estimators=1000, min_child_weight=1.0, max_depth=15, learning_rate=0.1, gamma=1.0, colsample_bytree=0.6, colsample_bylevel=0.9
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# [CV]  subsample=0.9, silent=False, reg_lambda=1.0, n_estimators=1000, min_child_weight=1.0, max_depth=15, learning_rate=0.1, gamma=1.0, colsample_bytree=0.6, colsample_bylevel=0.9, total=  52.9s
# [CV] subsample=0.5, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=1.0, max_depth=10, learning_rate=0.01, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=1.0
# [CV]  subsample=0.5, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=1.0, max_depth=10, learning_rate=0.01, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=1.0, total=   6.7s
# [CV] subsample=0.5, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=1.0, max_depth=10, learning_rate=0.01, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=1.0
# [CV]  subsample=0.5, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=1.0, max_depth=10, learning_rate=0.01, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=1.0, total=   6.9s
# [CV] subsample=0.9, silent=False, reg_lambda=10.0, n_estimators=1000, min_child_weight=7.0, max_depth=10, learning_rate=0.2, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=0.7
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# [CV]  subsample=0.9, silent=False, reg_lambda=10.0, n_estimators=1000, min_child_weight=7.0, max_depth=10, learning_rate=0.2, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=0.7, total=  40.5s
# [CV] subsample=0.9, silent=False, reg_lambda=10.0, n_estimators=1000, min_child_weight=7.0, max_depth=10, learning_rate=0.2, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=0.7
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# [CV]  subsample=0.9, silent=False, reg_lambda=10.0, n_estimators=1000, min_child_weight=7.0, max_depth=10, learning_rate=0.2, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=0.7, total=  43.7s
# [CV] subsample=0.8, silent=False, reg_lambda=50.0, n_estimators=1000, min_child_weight=5.0, max_depth=6, learning_rate=3, gamma=1.0, colsample_bytree=0.8, colsample_bylevel=1.0
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# [CV]  subsample=0.8, silent=False, reg_lambda=50.0, n_estimators=1000, min_child_weight=5.0, max_depth=6, learning_rate=3, gamma=1.0, colsample_bytree=0.8, colsample_bylevel=1.0, total=  13.7s
# [CV] subsample=0.8, silent=False, reg_lambda=50.0, n_estimators=1000, min_child_weight=5.0, max_depth=6, learning_rate=3, gamma=1.0, colsample_bytree=0.8, colsample_bylevel=1.0
# [CV]  subsample=0.8, silent=False, reg_lambda=50.0, n_estimators=1000, min_child_weight=5.0, max_depth=6, learning_rate=3, gamma=1.0, colsample_bytree=0.8, colsample_bylevel=1.0, total=   9.2s
# [CV] subsample=0.5, silent=False, reg_lambda=5.0, n_estimators=100, min_child_weight=10.0, max_depth=6, learning_rate=0.001, gamma=0, colsample_bytree=0.5, colsample_bylevel=0.7
# [CV]  subsample=0.5, silent=False, reg_lambda=5.0, n_estimators=100, min_child_weight=10.0, max_depth=6, learning_rate=0.001, gamma=0, colsample_bytree=0.5, colsample_bylevel=0.7, total=   2.0s
# [CV] subsample=0.5, silent=False, reg_lambda=5.0, n_estimators=100, min_child_weight=10.0, max_depth=6, learning_rate=0.001, gamma=0, colsample_bytree=0.5, colsample_bylevel=0.7
# [CV]  subsample=0.5, silent=False, reg_lambda=5.0, n_estimators=100, min_child_weight=10.0, max_depth=6, learning_rate=0.001, gamma=0, colsample_bytree=0.5, colsample_bylevel=0.7, total=   2.2s
# [CV] subsample=0.8, silent=False, reg_lambda=50.0, n_estimators=100, min_child_weight=5.0, max_depth=10, learning_rate=3, gamma=0, colsample_bytree=0.8, colsample_bylevel=0.4
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# [CV]  subsample=0.8, silent=False, reg_lambda=50.0, n_estimators=100, min_child_weight=5.0, max_depth=10, learning_rate=3, gamma=0, colsample_bytree=0.8, colsample_bylevel=0.4, total=   1.3s
# [CV] subsample=0.8, silent=False, reg_lambda=50.0, n_estimators=100, min_child_weight=5.0, max_depth=10, learning_rate=3, gamma=0, colsample_bytree=0.8, colsample_bylevel=0.4
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# [CV]  subsample=0.8, silent=False, reg_lambda=50.0, n_estimators=100, min_child_weight=5.0, max_depth=10, learning_rate=3, gamma=0, colsample_bytree=0.8, colsample_bylevel=0.4, total=   2.0s
# [CV] subsample=1.0, silent=False, reg_lambda=100.0, n_estimators=1000, min_child_weight=0.5, max_depth=15, learning_rate=0.2, gamma=1.0, colsample_bytree=0.5, colsample_bylevel=0.8
# [CV]  subsample=1.0, silent=False, reg_lambda=100.0, n_estimators=1000, min_child_weight=0.5, max_depth=15, learning_rate=0.2, gamma=1.0, colsample_bytree=0.5, colsample_bylevel=0.8, total=  51.9s
# [CV] subsample=1.0, silent=False, reg_lambda=100.0, n_estimators=1000, min_child_weight=0.5, max_depth=15, learning_rate=0.2, gamma=1.0, colsample_bytree=0.5, colsample_bylevel=0.8
# [CV]  subsample=1.0, silent=False, reg_lambda=100.0, n_estimators=1000, min_child_weight=0.5, max_depth=15, learning_rate=0.2, gamma=1.0, colsample_bytree=0.5, colsample_bylevel=0.8, total=  49.9s
# [CV] subsample=0.6, silent=False, reg_lambda=100.0, n_estimators=100, min_child_weight=10.0, max_depth=20, learning_rate=0, gamma=0.5, colsample_bytree=1.0, colsample_bylevel=0.4
# [CV]  subsample=0.6, silent=False, reg_lambda=100.0, n_estimators=100, min_child_weight=10.0, max_depth=20, learning_rate=0, gamma=0.5, colsample_bytree=1.0, colsample_bylevel=0.4, total=   3.0s
# [CV] subsample=0.6, silent=False, reg_lambda=100.0, n_estimators=100, min_child_weight=10.0, max_depth=20, learning_rate=0, gamma=0.5, colsample_bytree=1.0, colsample_bylevel=0.4
# [CV]  subsample=0.6, silent=False, reg_lambda=100.0, n_estimators=100, min_child_weight=10.0, max_depth=20, learning_rate=0, gamma=0.5, colsample_bytree=1.0, colsample_bylevel=0.4, total=   3.1s
# [CV] subsample=0.7, silent=False, reg_lambda=5.0, n_estimators=1000, min_child_weight=0.5, max_depth=20, learning_rate=3, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=0.4
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# [CV]  subsample=0.7, silent=False, reg_lambda=5.0, n_estimators=1000, min_child_weight=0.5, max_depth=20, learning_rate=3, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=0.4, total=   9.4s
# [CV] subsample=0.7, silent=False, reg_lambda=5.0, n_estimators=1000, min_child_weight=0.5, max_depth=20, learning_rate=3, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=0.4
# [CV]  subsample=0.7, silent=False, reg_lambda=5.0, n_estimators=1000, min_child_weight=0.5, max_depth=20, learning_rate=3, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=0.4, total=   5.9s
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/metrics/classification.py:2174: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 15.0min finished
# /home/safvan/.pyenv/versions/3.6.6/envs/bank_env/lib/python3.6/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# RandomizedSearchCV(cv=2, error_score='raise-deprecating',
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            colsample_bylevel=0.4,
#                                            colsample_bynode=1,
#                                            colsample_bytree=0.6, gamma=0.5,
#                                            learning_rate=0.1, max_delta_step=0,
#                                            max_depth=15, min_child_weight=0.5,
#                                            missing=None, n_estimators=1000,
#                                            n_jobs=1, nthread=8,
#                                            objective='binary:logistic',
#                                            random_state=0, reg_...
#                                         'gamma': [0, 0.25, 0.5, 1.0],
#                                         'learning_rate': [0.001, 0.01, 0.1, 0.2,
#                                                           0, 3],
#                                         'max_depth': [6, 10, 15, 20],
#                                         'min_child_weight': [0.5, 1.0, 3.0, 5.0,
#                                                              7.0, 10.0],
#                                         'n_estimators': [100, 1000],
#                                         'reg_lambda': [0.1, 1.0, 5.0, 10.0,
#                                                        50.0, 100.0],
#                                         'silent': [False],
#                                         'subsample': [0.5, 0.6, 0.7, 0.8, 0.9,
#                                                       1.0]},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=False,
#                    return_train_score=False, scoring='neg_log_loss', verbose=2)

# %%
best_score = rs_clf.best_score_
best_params = rs_clf.best_params_

# %%
for param_name in sorted(best_params.keys()):
    print('%s= %r,' % (param_name, best_params[param_name]))
# Out:
# colsample_bylevel= 0.8,
# colsample_bytree= 0.5,
# gamma= 1.0,
# learning_rate= 0.2,
# max_depth= 15,
# min_child_weight= 0.5,
# n_estimators= 1000,
# reg_lambda= 100.0,
# silent= False,
# subsample= 1.0,
